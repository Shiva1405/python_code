# %%
a=12
b=3
c=a*b
print(c)
# Out:
# 36

# %%
#eval
a=eval(input())
print()
# Out:
# a

# %%
l=['a','e','i','o','u']
l1=[0,0,0,0,0]
l2=[]
r=str(input("enter the scentence"))
for i in r:
  if i in "aeiou":
    l2.append(i)
    l1[l.index(i)]+=1 
print("vowel in a scentence"+str(l2))
print("each vowel repeated as"+str(l1))
# Out:
# enter the scentencei am the boss
# vowel in a scentence['i', 'a', 'e', 'o']
# each vowel repeated as[1, 1, 1, 1, 0]

# %%
age=int(input())
if(age<12):
  print("toy")
if(age>12 and age<31):
  print("chocolate")
else: 
  print("shawl")
# Out:
# 51
# shawl

# %%
import random
r=int(random.random()*10)

t=input("Enter your birth time:")
d=input("Enter your dob [dd/mm/yyyy]:")
print("Lets begin your life journey \n We are just born")
if((int(d[:-8])+r)%2==0):
  print("\t You are toodler and probably like sweets")
elif((int(d[:-8])+r)%3==0):
  print('\t You are toodler and probably like sour')
else:
  print("\t You are toodler and probably like spicy")  
print("Now you became a kid")
if((int(d[3:-5])+r)%2==0):
  print("\t You are a kid and may get a cycle")
else:
  print('\t You are a kid and may get toy')
print("You are a teenager")
if((int(d[6:-1])+r)%2==0):
  print("\tYou may have an iteraction with crush")    
else:
  print("\t Opps! You didn't havec chance to interact with crush")
print("Its time to gets serious")
if((int(t[0:1])+r)%2==0):
  print("\t You might like pcm stream")
else:
  print("\t You might like pcb stream")
print("Hurrey! It your time to celebrate fairwell ")  
if((int(d[:-8])+r)%2==0):
  print("\t You are going to meet crush and You going to propose your crush")
else:
  print("\t You are couple of time with your crush but you are going not to propose")
print("Its time to follow your own career")
if((int(d[:-8])+r)%2==0):
  print("\t You are going to follow your talent")
elif((int(d[:-8])+r)%3==0):
  print('\t You are going to do bussiness')
else:
  print("\t You are going to follow your profession")
print("Now,You are going to recieve partner in your life")
if((int(t[0:1])+r)%2==0):
  print("\t You may get partner by love marriage")
else:
  print("\t You may get partner by arrange marriage")
print("After marriage,you have to choose honeymoon destination")
if((int(d[3:5])+r)%2==0):
 print("\t Destination place is maldives")
elif((int(d[3:5])+r)%3==0):
  print("\t Destination place is Ladak")
else:
  print("\t Destination place is all over india")
print("Its time of your honeymoon result")  
if((int(d[6:-1])+r)%2==0):
  print("\t You are became of parent "+str(r)+" children ")    
else:
  print("\t You are became of parent "+str(r)+" children")
print("Its time to leave duties ")
if((int(d[3:-5])+r)%2==0):
  print("\t Enjoy your life at hill station")
else:
  print('\t Enjoy your journy at holy place')
# Out:
# Enter your birth time:4
# Enter your dob [dd/mm/yyyy]:12/08/1995
# Lets begin your life journey
#  We are just born
# 	 You are toodler and probably like sweets
# Now you became a kid
# 	 You are a kid and may get a cycle
# You are a teenager
# 	 Opps! You didn't havec chance to interact with crush
# Its time to gets serious
# 	 You might like pcm stream
# Hurrey! It your time to celebrate fairwell
# 	 You are going to meet crush and You going to propose your crush
# Its time to follow your own career
# 	 You are going to follow your talent
# Now,You are going to recieve partner in your life
# 	 You may get partner by love marriage
# After marriage,you have to choose honeymoon destination
# 	 Destination place is maldives
# Its time of your honeymoon result
# 	 You are became of parent 4 children
# Its time to leave duties
# 	 Enjoy your life at hill station

# %%
"
x="   jay ho    "
print(x.split())
print(x.find("j"))
print(x.strip())
# Out:
# ['jay', 'ho']
# 3
# jay ho

# %%
def sum(a,b):
  return(a+b)
sum(6,7)
# Out:
# 13

# %%
k=int(input("Message Sender : \n Hello MIT CELL: \n Please enter k value to shift transform message:"))
output=""
s=input('Now please type your message:')
for x in s:
  if x in "!@#$%^&*()-+?_=,<>/":
    output+=x
  elif x ==" ":
    output+="@"
  elif x ==".":
    output+="#"
  else:
    y=ord(x)+k
    m=chr(y)
    output+=m
print("You send-"+output)
print("Message Receiver :\n Hello Instructor: \n You got a message:"+output)
k=int(input("to read this message enter the value of k provided by cell"))
output1=""
for x in output:
  if x in "!@#$%^&*()-+?_=,<>/":
    output1+=x
  elif x =="@":
    output1+=" "
  elif x =="#":
    output1+="."
  else:
    y=ord(x)-k
    m=chr(y)
    output1+=m
print("Original Message:"+output1)
# Out:
# Message Sender :
#  Hello MIT CELL:
#  Please enter k value to shift transform message:3
# Now please type your message:AB%c123*.
# You send-DE%f456*#
# Message Receiver :
#  Hello Instructor:
#  You got a message:DE%f456*#
# to read this message enter the value of k provided by cell3
# Original Message:AB%c123*#

# %%
balance=450
class amt:
  def deposit(self,v):
    global balance
    balance += v
  def withdrwal(self,w):
    global balance
    balance-=w
ddd=amt()
ddd.deposit(200)
ddd.withdrwal(50)
print(balance)
# Out:
# 600

# %%
class chatting:
  def msg(self):
    print("hi")
  def rply(self):
    print("hii")
frnd=chatting()
frnd.msg()
frnd.rply()
# Out:
# hi
# hii

# %%
class customer:
  def __int__(self,c_id,c_name,c_pass,c_address,c_phone,c_email):
    self.c_id=c_id
    self.c_name=c_name
    self.c_pass=c_name
    self.c_address=c_address
    self.c_phone=c_phone
    self.c_email=c_email
  def register(self):
  def login(self):
  def add_item(self):
  def details(self):
  def add_to_cart(self):
  def cost_cal(self):
  def select_pay(self):
  def logout(self):
  
  
customers=customer(1,"Lucky","Silver","mbd",965555555,"jay@gmail.com")
class admin:
  a_email,a_pass
  def login(self):
  def manage order(self):
  def manage product(self):

class cart:
  c_id,p_id,p_pict,p_name,p_price,p_quantity,p_subtotal
  def UPDATE_CART(self):
  def DELETE_CART(self):

class order:
  o_id,p_id,u_id,subtotal,status,quantity
  def find_Details(self):

class product:
  p_id,p_name,p_description,p_catid,p_price,p_pict,p_suppler
  def available_stock(self):
  def get_product(self):

class payment:
  amount,date,payment no
  def payment_details(self):
  def slip_generation(self):
class offline_online:
  account,cart no,bank authentication,address,COD,received

class order_status:
  NEW,HOLD,SHIPPED,DELIVERED,CLOSE 

class account:
  ID,BILLING-ADDRESS,ISCLOSED,OPEN,CLOSE
# Out:
#   File "<ipython-input-4-b95546699043>", line 11
#     def login(self):
#       ^
# IndentationError: expected an indented block

# %%
import random
r=int(random.random()*10)

# %%
class Person:
  def printname(self,firstname,lastname):
    print(firstname+" "+lastname)

class Student:
  def welcome(self,firstname,lastname,graduationyear):
    print("Welcome"+firstname+" "+lastname+" to the class of "+str(graduationyear))
class stream(Person,Student):
  def hi():
    print("hiiiiiii")

x = stream()
x.welcome("Momo","koko",2000)
x.printname("Jojo","Zozo")
y=stream()
y.printname("Zozo","JOJO")
# Out:
# WelcomeMomo koko to the class of 2000
# Jojo Zozo
# Zozo JOJO
